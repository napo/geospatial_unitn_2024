# %% [markdown]
# # Basis for mobility analysis
#
# based on osnmx, grapphoper and movingpandas
# goals of the tutorial
#
# - basic concepts of network analysis
# - routing
# - bearing
# - isochrones
# - GPX format
# - mapmatching
# - analysis of movements
#
# based on the open data of:
# - OpenStreetMap
#
# requirements
# - python knowledge
# - geopandas
# - openstreetmap
#
# status<br/>
# “Where's Wally?”

# %% [markdown]
# ---
#
# # Setup
# for this tutorial we will use [OSMnx](https://github.com/gboeing/osmnx) = (openstreetmap + [networkx](https://networkx.org/))
#
# Boeing, G. 2017. "[OSMnx: New Methods for Acquiring, Constructing, Analyzing, and Visualizing Complex Street Networks.](https://geoffboeing.com/publications/osmnx-complex-street-networks/)" *Computers, Environment and Urban Systems 65, 126-139. doi:10.1016/j.compenvurbsys.2017.05.004*

# %%
pip install -r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt
# Out:
# Requirement already satisfied: mapclassify==2.8.1 in /usr/local/lib/python3.10/dist-packages (from -r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 1)) (2.8.1)
# Requirement already satisfied: matplotlib==3.7.1 in /usr/local/lib/python3.10/dist-packages (from -r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 2)) (3.7.1)
# Requirement already satisfied: xlrd==2.0.1 in /usr/local/lib/python3.10/dist-packages (from -r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 3)) (2.0.1)
# Requirement already satisfied: requests==2.32.3 in /usr/local/lib/python3.10/dist-packages (from -r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 4)) (2.32.3)
# Requirement already satisfied: geopy==2.4.1 in /usr/local/lib/python3.10/dist-packages (from -r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 5)) (2.4.1)
# Requirement already satisfied: osmnx==1.9.4 in /usr/local/lib/python3.10/dist-packages (from -r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 6)) (1.9.4)
# Requirement already satisfied: polyline==2.0.2 in /usr/local/lib/python3.10/dist-packages (from -r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 7)) (2.0.2)
# Requirement already satisfied: gpxpy==1.6.2 in /usr/local/lib/python3.10/dist-packages (from -r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 8)) (1.6.2)
# Requirement already satisfied: hvplot==0.11.0 in /usr/local/lib/python3.10/dist-packages (from -r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 9)) (0.11.0)
# Requirement already satisfied: geoviews==1.13.0 in /usr/local/lib/python3.10/dist-packages (from -r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 10)) (1.13.0)
# Requirement already satisfied: movingpandas==0.19.0 in /usr/local/lib/python3.10/dist-packages (from -r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 11)) (0.19.0)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.10/dist-packages (from mapclassify==2.8.1->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 1)) (3.3)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.10/dist-packages (from mapclassify==2.8.1->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 1)) (1.26.4)
# Requirement already satisfied: pandas!=1.5.0,>=1.4 in /usr/local/lib/python3.10/dist-packages (from mapclassify==2.8.1->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 1)) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.10/dist-packages (from mapclassify==2.8.1->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 1)) (1.5.2)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.10/dist-packages (from mapclassify==2.8.1->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 1)) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 2)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 2)) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 2)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 2)) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 2)) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 2)) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib==3.7.1->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 2)) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests==2.32.3->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 4)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests==2.32.3->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 4)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests==2.32.3->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 4)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests==2.32.3->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 4)) (2024.8.30)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.10/dist-packages (from geopy==2.4.1->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 5)) (2.0)
# Requirement already satisfied: geopandas<0.15,>=0.12 in /usr/local/lib/python3.10/dist-packages (from osmnx==1.9.4->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 6)) (0.14.4)
# Requirement already satisfied: shapely<2.1,>=2.0 in /usr/local/lib/python3.10/dist-packages (from osmnx==1.9.4->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 6)) (2.0.6)
# Requirement already satisfied: bokeh>=3.1 in /usr/local/lib/python3.10/dist-packages (from hvplot==0.11.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 9)) (3.5.2)
# Requirement already satisfied: colorcet>=2 in /usr/local/lib/python3.10/dist-packages (from hvplot==0.11.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 9)) (3.1.0)
# Requirement already satisfied: holoviews>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from hvplot==0.11.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 9)) (1.19.1)
# Requirement already satisfied: panel>=1.0 in /usr/local/lib/python3.10/dist-packages (from hvplot==0.11.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 9)) (1.5.2)
# Requirement already satisfied: param<3.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from hvplot==0.11.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 9)) (2.1.1)
# Requirement already satisfied: cartopy>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from geoviews==1.13.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 10)) (0.24.1)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.10/dist-packages (from geoviews==1.13.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 10)) (3.7.0)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.10/dist-packages (from geoviews==1.13.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 10)) (2024.9.0)
# Requirement already satisfied: fiona in /usr/local/lib/python3.10/dist-packages (from movingpandas==0.19.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 11)) (1.10.1)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from bokeh>=3.1->hvplot==0.11.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 9)) (3.1.4)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.10/dist-packages (from bokeh>=3.1->hvplot==0.11.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 9)) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in /usr/local/lib/python3.10/dist-packages (from bokeh>=3.1->hvplot==0.11.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 9)) (6.3.3)
# Requirement already satisfied: pyshp>=2.3 in /usr/local/lib/python3.10/dist-packages (from cartopy>=0.18.0->geoviews==1.13.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 10)) (2.3.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona->movingpandas==0.19.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 11)) (24.2.0)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona->movingpandas==0.19.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 11)) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona->movingpandas==0.19.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 11)) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona->movingpandas==0.19.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 11)) (0.7.2)
# Requirement already satisfied: pyviz-comms>=2.1 in /usr/local/lib/python3.10/dist-packages (from holoviews>=1.19.0->hvplot==0.11.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 9)) (3.0.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.5.0,>=1.4->mapclassify==2.8.1->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 1)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas!=1.5.0,>=1.4->mapclassify==2.8.1->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 1)) (2024.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from panel>=1.0->hvplot==0.11.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 9)) (6.1.0)
# Requirement already satisfied: linkify-it-py in /usr/local/lib/python3.10/dist-packages (from panel>=1.0->hvplot==0.11.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 9)) (2.0.3)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from panel>=1.0->hvplot==0.11.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 9)) (3.7)
# Requirement already satisfied: markdown-it-py in /usr/local/lib/python3.10/dist-packages (from panel>=1.0->hvplot==0.11.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 9)) (3.0.0)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.10/dist-packages (from panel>=1.0->hvplot==0.11.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 9)) (0.4.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from panel>=1.0->hvplot==0.11.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 9)) (4.66.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from panel>=1.0->hvplot==0.11.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 9)) (4.12.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib==3.7.1->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 2)) (1.16.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0->mapclassify==2.8.1->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 1)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0->mapclassify==2.8.1->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 1)) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.9->bokeh>=3.1->hvplot==0.11.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 9)) (2.1.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->panel>=1.0->hvplot==0.11.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 9)) (0.5.1)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.10/dist-packages (from linkify-it-py->panel>=1.0->hvplot==0.11.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 9)) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py->panel>=1.0->hvplot==0.11.0->-r https://napo.github.io/geospatial_unitn_2024/requirements_mobility.txt (line 9)) (0.1.2)

# %%
import geopandas as gpd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Let’s start with OSMnx

# %%
import osmnx as ox
import matplotlib.pyplot as plt

# %% [markdown]
# ## prepare the data

# %%
place_name = "Venezia, Lido, Venice, Venezia, Veneto, Italy"

# %% [markdown]
# .. and we can extract all the streets where it's possible to drive
#
# OSMnx creates a overpass query to ask the data inside the area of name of the city and collect all the [highways](https://wiki.openstreetmap.org/wiki/Key:highway) where a car can move
#
# Eg.<br/>
# https://overpass-turbo.eu/s/1nnv
#
# ![](https://raw.githubusercontent.com/napo/geospatial_course_unitn/master/images/mezzolombardo_streets.png)

# %%
G = ox.graph_from_place(place_name, network_type='all')

# %% [markdown]
# OSMnx transform the data from OpenStreetMap in [graph](https://networkx.org/documentation/stable/reference/introduction.html#graphs) for [networkx](https://networkx.org/)

# %% [markdown]
# # Graph Theory
# text from [wikipedia](https://en.wikipedia.org/wiki/Graph_theory)
#
#
#
# A graph is made up of **vertices** (also called *nodes* or *points*) which are connected by **edges** (also called *links* or *lines*)
#
# A distinction is made between undirected graphs, where edges link two vertices symmetrically, and directed graphs, where edges link two vertices asymmetrically;
#
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/b/bf/Undirected.svg/267px-Undirected.svg.png)
#
# Example<br/>
# undirected graph with three nodes and three edges.
#
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/a/a2/Directed.svg/267px-Directed.svg.png)
#
# Example<br/>
# a directed graph with three vertices and four directed edges<br/>(the double arrow represents an edge in each direction).

# %% [markdown]
# the type of graph generated by OSMnx is a MultiDiGraph: a directed graphs with self loops and parallel edges
#
# more information [here](https://networkx.org/documentation/stable/reference/classes/multidigraph.html)

# %%
type(G)
# Out:
# networkx.classes.multidigraph.MultiDiGraph

# %% [markdown]
# OSMnx converts the graph from latitude/longitude (WGS83) to the right UTM coordinate reference system for the area selected

# %%
G_proj = ox.project_graph(G)

# %% [markdown]
# from osmnx you can create geodataframes (gdfs) from a netxworkx Graph

# %%
gdfs = ox.graph_to_gdfs(G_proj)

# %%
type(gdfs)
# Out:
# tuple

# %% [markdown]
# 0 => nodes (points)<br/>
# 1 => edges (lines)

# %%
type(gdfs[0])
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
gdfs[0].geometry.type.unique()
# Out:
# array(['Point'], dtype=object)

# %%
gdfs[1].geometry.type.unique()
# Out:
# array(['LineString'], dtype=object)

# %%
gdfs[1].crs
# Out:
# <Projected CRS: EPSG:32633>
# Name: WGS 84 / UTM zone 33N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 12°E and 18°E, northern hemisphere between equator and 84°N, onshore and offshore. Austria. Bosnia and Herzegovina. Cameroon. Central African Republic. Chad. Congo. Croatia. Czechia. Democratic Republic of the Congo (Zaire). Gabon. Germany. Hungary. Italy. Libya. Malta. Niger. Nigeria. Norway. Poland. San Marino. Slovakia. Slovenia. Svalbard. Sweden. Vatican City State.
# - bounds: (12.0, 0.0, 18.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 33N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# extract only the nodes (projected)

# %%
nodes_proj = ox.graph_to_gdfs(G_proj, edges=False, nodes=True)

# %%
type(nodes_proj)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
nodes_proj.crs
# Out:
# <Projected CRS: EPSG:32633>
# Name: WGS 84 / UTM zone 33N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 12°E and 18°E, northern hemisphere between equator and 84°N, onshore and offshore. Austria. Bosnia and Herzegovina. Cameroon. Central African Republic. Chad. Congo. Croatia. Czechia. Democratic Republic of the Congo (Zaire). Gabon. Germany. Hungary. Italy. Libya. Malta. Niger. Nigeria. Norway. Poland. San Marino. Slovakia. Slovenia. Svalbard. Sweden. Vatican City State.
# - bounds: (12.0, 0.0, 18.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 33N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
nodes_proj.plot()
plt.show()

# %%
lines_proj = ox.graph_to_gdfs(G_proj, nodes=False)

# %%
lines_proj.plot()
plt.show()

# %% [markdown]
# ... and we can use it as a normal geodaframe<br/>
#
# Eg:<br/>
# what sized area does our network cover in square meters?

# %%
nodes_proj.unary_union.convex_hull
# Out:
# <POLYGON ((293916.97 5033563.196, 293771.462 5033570.535, 293752.266 5033571...>

# %%
graph_area_m = nodes_proj.unary_union.convex_hull.area
graph_area_m
# Out:
# 7680896.287018098

# %% [markdown]
# with OSMnx we can extract some basic statistics

# %%
ox.basic_stats(G_proj, area=graph_area_m, clean_int_tol=15)
# Out:
# {'n': 5572,
#  'm': 14163,
#  'k_avg': 5.083632447954056,
#  'edge_length_total': 400337.39299999975,
#  'edge_length_avg': 28.26642611028735,
#  'streets_per_node_avg': 2.5838119167264897,
#  'streets_per_node_counts': {0: 0,
#   1: 1437,
#   2: 4,
#   3: 3613,
#   4: 489,
#   5: 20,
#   6: 6,
#   7: 3},
#  'streets_per_node_proportions': {0: 0.0,
#   1: 0.25789662598707824,
#   2: 0.0007178750897343862,
#   3: 0.6484206748025844,
#   4: 0.08776022972002871,
#   5: 0.003589375448671931,
#   6: 0.0010768126346015793,
#   7: 0.0005384063173007897},
#  'intersection_count': 4135,
#  'street_length_total': 203812.66500000036,
#  'street_segment_count': 7178,
#  'street_length_avg': 28.39407425466709,
#  'circuity_avg': 1.0655998312063035,
#  'self_loop_proportion': 0.0032042351629980497,
#  'clean_intersection_count': 700,
#  'node_density_km': 725.4361720021583,
#  'intersection_density_km': 538.34863087382,
#  'edge_density_km': 52121.18196109897,
#  'street_density_km': 26535.010678958817,
#  'clean_intersection_density_km': 91.13519748770833}

# %% [markdown]
# stats documentation: [https://osmnx.readthedocs.io/en/stable/osmnx.html#module-osmnx.stats](https://osmnx.readthedocs.io/en/stable/osmnx.html#module-osmnx.stats)

# %% [markdown]
# ## Glossary of the terms used by the statistics
#
# For a complete list look the [networkx documentation](https://networkx.org/documentation/stable/)
#
# - **density**<br/>defines the density of a graph. The density is 0 for a graph without edges and 1 for a complete graph. The density of multigraphs can be higher than 1.
# - **center**<br/>is the set of points with eccentricity equal to radius.
# - **betwnees centrality**<br/>is the number of possible interactions between two non-adjacent points
# - **closeness centrality**<br/>is the average distance of a point from all the others
# - **clustering coefficient**<br/>the measure of the degree to which points in a graph tend to cluster together
# - **degree centrality**<br/>the number of lines incident upon a point
# - **eccentricity** <br/>the eccentricity of a point in a graph is defined as the length of a longest shortest path starting at that point
# - **diameter**<br/>the maximum eccentricity
# - **edge connectivity**<br/>
# is equal to the minimum number of edges that must be removed to disconnect a graph or render it trivial.
# - **node connectivity**<br/>
# is equal to the minimum number of points that must be removed to disconnect a graph or render it trivial.
# - **pagerank**<br/>
# computes a ranking of the nodes (points) in a graph based on the structure of the incoming links (lines). It was originally designed as an algorithm to rank web pages.
# - **periphery** <br/>is the set of nodes with eccentricity equal to the diameter
# - **radius**<br/>is the minimum eccentricity.

# %% [markdown]
# ... and we can plot the map

# %%
fig, ax = ox.plot_graph(G)
plt.show()

# %%
import networkx as nx

# %%
# convert graph to line graph so edges become nodes and vice versa
edge_centrality = nx.closeness_centrality(nx.line_graph(G))
nx.set_edge_attributes(G, edge_centrality, 'edge_centrality')

# %%
# color edges in original graph with closeness centralities from line graph
ec = ox.plot.get_edge_colors_by_attr(G, 'edge_centrality', cmap='inferno')
fig, ax = ox.plot_graph(G, edge_color=ec, edge_linewidth=2, node_size=0)
plt.show()

# %% [markdown]
# # Find the shortest path between 2 points by minimizing travel time

# %% [markdown]
# ## calculate the travel time for each edge

# %% [markdown]
# ### define the origin and destination
# Example:
#
# from the train station of Venezia Santa Lucia to the Rialto Bridge

# %% [markdown]
# **train station**
#
# [Venezia Santa Lucia](https://www.openstreetmap.org/node/6063641885)
#
# lat: 45.4410753<br/>
# lon: 12.3210322
#
#
# **Rialto Bridge**
#
# [Ponte di Rialto](https://www.openstreetmap.org/way/199258374)
#
# lat: 45.43805<br/>
# lon: 12.33593

# %% [markdown]
# ## find the node on the graph nearest on the point given
#
# thes two points are NOT on the graph.
#
# We need to find the nodes nearest

# %%
point_nearest_train_station = ox.distance.nearest_nodes(G,Y=45.4410753,X=12.3210322)
point_nearest_bridge_rialto = ox.distance.nearest_nodes(G,Y=45.43805,X=12.33593)

# %%
# impute missing edge speeds and calculate edge travel times with the speed module
G = ox.speed.add_edge_speeds(G)
G = ox.speed.add_edge_travel_times(G)

# %% [markdown]
# ### calculate the time to walk over each edges

# %%
G = ox.graph_from_place(place_name, network_type='walk')

# %% [markdown]
# plot the walkable street network

# %%
fig, ax = ox.plot_graph(G)
plt.show()

# %%
G = ox.add_edge_speeds(G)
G = ox.add_edge_travel_times(G)

# %% [markdown]
# ... geopandas investigation

# %%
edges = ox.graph_to_gdfs(G,edges=True,nodes=False)

# %%
edges.head(3)
# Out:
#                              osmid bridge             name  highway  oneway  \
# u        v          key
# 27178184 764403528  0    166489461    yes  Ponte di Rialto  footway   False
#          1675825096 0    166489461    yes  Ponte di Rialto  footway   False
#          8670969688 0    450089474    yes  Ponte di Rialto    steps   False
#
#                         reversed  length  speed_kph  travel_time width  \
# u        v          key
# 27178184 764403528  0      False   9.935       43.0          0.8   NaN
#          1675825096 0       True   5.120       43.0          0.4   NaN
#          8670969688 0      False   9.212       43.0          0.8     7
#
#                                                                   geometry  \
# u        v          key
# 27178184 764403528  0    LINESTRING (12.33569 45.43820, 12.33561 45.43813)
#          1675825096 0    LINESTRING (12.33569 45.43820, 12.33573 45.43823)
#          8670969688 0    LINESTRING (12.33569 45.43820, 12.33560 45.43825)
#
#                         tunnel lanes maxspeed est_width access area service  \
# u        v          key
# 27178184 764403528  0      NaN   NaN      NaN       NaN    NaN  NaN     NaN
#          1675825096 0      NaN   NaN      NaN       NaN    NaN  NaN     NaN
#          8670969688 0      NaN   NaN      NaN       NaN    NaN  NaN     NaN
#
#                         junction
# u        v          key
# 27178184 764403528  0        NaN
#          1675825096 0        NaN
#          8670969688 0        NaN

# %%
edges.columns
# Out:
# Index(['osmid', 'bridge', 'name', 'highway', 'oneway', 'reversed', 'length',
#        'speed_kph', 'travel_time', 'width', 'geometry', 'tunnel', 'lanes',
#        'maxspeed', 'est_width', 'access', 'area', 'service', 'junction'],
#       dtype='object')

# %%
edges[edges.travel_time == edges.travel_time.max()].name
# Out:
# u            v            key
# 1927219469   11182286836  0      NaN
# 11182286836  1927219469   0      NaN
# Name: name, dtype: object

# %%
edges[edges.travel_time == edges.travel_time.max()].osmid
# Out:
# u            v            key
# 1927219469   11182286836  0      [404610512, 404610513]
# 11182286836  1927219469   0      [404610512, 404610513]
# Name: osmid, dtype: object

# %% [markdown]
# ![](https://raw.githubusercontent.com/napo/geospatial_course_unitn/master/images/osmid_3400471.jpg)
#
# https://www.openstreetmap.org/way/404610513

# %% [markdown]
# ## find the shortest path between the train station and Rialto bridge

# %%
# find the shortest path between nodes, minimizing travel time, then plot it
route = ox.shortest_path(G, point_nearest_train_station, point_nearest_bridge_rialto, weight="travel_time")

# %%
route
# Out:
# [1927219479,
#  3527986497,
#  2493856508,
#  9055796707,
#  1921651801,
#  27239442,
#  5372700772,
#  4899902714,
#  1855450146,
#  3371984917,
#  2514483400,
#  1858198295,
#  1858198260,
#  3371984290,
#  3371984894,
#  5360645772,
#  1855473678,
#  1855473687,
#  4849873712,
#  4849867342,
#  1856706712,
#  3389313497,
#  5149979474,
#  2732099927,
#  4843929370,
#  2732099913,
#  2732099919,
#  2732099909,
#  2732099904,
#  4803731379,
#  4846061555,
#  1857205293,
#  1857205276,
#  4793615634,
#  1857205288,
#  1856788519,
#  3392463420,
#  3392463416,
#  1857148236,
#  1840378080,
#  2249214723,
#  4803872602,
#  4803871721,
#  1857139330,
#  4902225461,
#  6026202973,
#  1857139318,
#  1857139273,
#  1857139324,
#  1857139332,
#  4983211717,
#  4983211715,
#  5649829357,
#  282975977,
#  4821479726,
#  4977488959,
#  4982153142,
#  4982195156,
#  4982195157,
#  8670969688,
#  27178184,
#  5395065019]

# %% [markdown]
# these values are the ids of each node of the graph

# %%
G.nodes[5395065019]
# Out:
# {'y': 45.4380532, 'x': 12.3359319, 'street_count': 4}

# %%
nodes = ox.graph_to_gdfs(G,edges=False,nodes=True)

# %%
nodes
# Out:
#                      y          x  street_count highway  \
# osmid
# 27178184     45.438197  12.335686             4     NaN
# 27178422     45.432325  12.337206             4     NaN
# 27178423     45.432482  12.337658             3     NaN
# 27178433     45.429240  12.327350             3     NaN
# 27223839     45.434570  12.350321             3     NaN
# ...                ...        ...           ...     ...
# 11947815750  45.432363  12.313916             3     NaN
# 12060946143  45.445841  12.323660             1     NaN
# 12060946144  45.446070  12.323787             1     NaN
# 12162296576  45.437852  12.318690             3     NaN
# 12229352013  45.437045  12.324212             1     NaN
#
#                               geometry
# osmid
# 27178184     POINT (12.33569 45.43820)
# 27178422     POINT (12.33721 45.43233)
# 27178423     POINT (12.33766 45.43248)
# 27178433     POINT (12.32735 45.42924)
# 27223839     POINT (12.35032 45.43457)
# ...                                ...
# 11947815750  POINT (12.31392 45.43236)
# 12060946143  POINT (12.32366 45.44584)
# 12060946144  POINT (12.32379 45.44607)
# 12162296576  POINT (12.31869 45.43785)
# 12229352013  POINT (12.32421 45.43705)
#
# [5310 rows x 5 columns]

# %%
fig, ax = ox.plot_graph_route(G, route, route_linewidth=6, node_size=0, bgcolor='k')
plt.show()

# %%
ox.plot_route_folium(G,route,popup_attribute='name',tiles='CartoDB dark_matter')
#OpenStreetMap
#Stamen Terrain
#Steman Toner
#Stamen Watercolor
#CartoDB positron
#CartoDB dark_matter
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6a6e80535019e01908dc5c21cf22a0de {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6a6e80535019e01908dc5c21cf22a0de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6a6e80535019e01908dc5c21cf22a0de = L.map(
#                 &quot;map_6a6e80535019e01908dc5c21cf22a0de&quot;,
#                 {
#                     center: [45.43974455415212, 12.32836901398607],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1572b609954972ccf49f9f1f4b6f132d = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1572b609954972ccf49f9f1f4b6f132d.addTo(map_6a6e80535019e01908dc5c21cf22a0de);
#
#
#             var poly_line_ed0a71e016550bfbfe359aeaa9ee5465 = L.polyline(
#                 [[45.4410566, 12.3210338], [45.4409662, 12.3211934], [45.4409512, 12.3212199]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6a6e80535019e01908dc5c21cf22a0de);
#
#
#         var popup_4349cc10ef769ae03e6994df9a909a76 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_31573a49aa59f91d5a917dad8c2641c9 = $(`&lt;div id=&quot;html_31573a49aa59f91d5a917dad8c2641c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NaN&lt;/div&gt;`)[0];
#                 popup_4349cc10ef769ae03e6994df9a909a76.setContent(html_31573a49aa59f91d5a917dad8c2641c9);
#
#
#
#         poly_line_ed0a71e016550bfbfe359aeaa9ee5465.bindPopup(popup_4349cc10ef769ae03e6994df9a909a76)
#         ;
#
#
#
#
#             var poly_line_6b0c533dbaacd84d37a54a5d799d365e = L.polyline(
#                 [[45.4409512, 12.3212199], [45.4409389, 12.3212416], [45.4408913, 12.3213256], [45.4407422, 12.3215889]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6a6e80535019e01908dc5c21cf22a0de);
#
#
#         var popup_8933b581d602cba79c6e5e964ac0fdf0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_32def312c99fd012eb498cd7f49de6dd = $(`&lt;div id=&quot;html_32def312c99fd012eb498cd7f49de6dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NaN&lt;/div&gt;`)[0];
#                 popup_8933b581d602cba79c6e5e964ac0fdf0.setContent(html_32def312c99fd012eb498cd7f49de6dd);
#
#
#
#         poly_line_6b0c533dbaacd84d37a54a5d799d365e.bindPopup(popup_8933b581d602cba79c6e5e964ac0fdf0)
#         ;
#
#
#
#
#             var poly_line_9b7c007416a1b21df42c74b5b99464f8 = L.polyline(
#                 [[45.4407422, 12.3215889], [45.4410066, 12.3218645], [45.4410189, 12.3218773]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6a6e80535019e01908dc5c21cf22a0de);
#
#
#         var popup_96f789ca4f4a23b98ce9955eb61a7a9d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c5883242b2fbbc7e1a6b214ec5900e0b = $(`&lt;div id=&quot;html_c5883242b2fbbc7e1a6b214ec5900e0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&quot;Fondamenta Santa Lucia&quot;&lt;/div&gt;`)[0];
#                 popup_96f789ca4f4a23b98ce9955eb61a7a9d.setContent(html_c5883242b2fbbc7e1a6b214ec5900e0b);
#
#
#
#         poly_line_9b7c007416a1b21df42c74b5b99464f8.bindPopup(popup_96f789ca4f4a

# %% [markdown]
# how long is our route in meters?

# %%
edge_lengths = ox.utils_graph.get_route_edge_attributes(G, route, 'length')
sum(edge_lengths)
# Out:
# 1614.0579999999998

# %% [markdown]
# how many minutes does it take?

# %%
import datetime

# %%
edge_times = ox.utils_graph.get_route_edge_attributes(G, route, 'travel_time')
seconds = sum(edge_times)

# %%
seconds
# Out:
# 135.29999999999998

# %%
str(datetime.timedelta(seconds=seconds))
# Out:
# '0:02:15.300000'

# %% [markdown]
# ## calculate bearing
#
# Calculate the compass bearing from origin node to destination node for each edge in the directed graph then add each bearing as a new edge attribute. Bearing represents angle in degrees (clockwise) between north and the direction from the origin node to the destination node.
# <br/><br/>

# %%
cols = ['city']
names = [('Roma'),('Trento'),('Genova'),('Trieste'),('Venezia')]
cities = gpd.GeoDataFrame(names,columns=cols)
geo_cities = gpd.tools.geocode(cities.city, provider="arcgis")

# %%
cities
# Out:
#       city
# 0     Roma
# 1   Trento
# 2   Genova
# 3  Trieste
# 4  Venezia

# %%
geo_cities
# Out:
#                     geometry  address
# 0  POINT (12.49427 41.89056)     Roma
# 1  POINT (11.11907 46.06667)   Trento
# 2   POINT (8.93399 44.40706)   Genova
# 3  POINT (13.77852 45.65360)  Trieste
# 4  POINT (12.33891 45.43461)  Venezia

# %%
trento = geo_cities[geo_cities.address == 'Trento'].geometry

# %%
trento.geometry.x.values[0]
# Out:
# 11.1190676

# %%
roma = geo_cities[geo_cities.address == 'Roma']
genova = geo_cities[geo_cities.address == 'Genova']
trieste = geo_cities[geo_cities.address == 'Trieste']
venezia = geo_cities[geo_cities.address == 'Venezia']

# %% [markdown]
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/2/29/Compass_Card_B%2BW.svg/480px-Compass_Card_B%2BW.svg.png)

# %%
#Trento - Roma
ox.bearing.calculate_bearing(trento.geometry.y.values[0],trento.geometry.x.values[0],roma.geometry.y.values[0],roma.geometry.x.values[0])
# Out:
# 166.18753350290405

# %%
#Trento - Trieste
ox.bearing.calculate_bearing(trento.geometry.y.values[0],trento.geometry.x.values[0],trieste.geometry.y.values[0],trieste.geometry.x.values[0])
# Out:
# 101.61637981132255

# %%
#Trento - Venezia
ox.bearing.calculate_bearing(trento.geometry.y.values[0],trento.geometry.x.values[0],venezia.geometry.y.values[0],venezia.geometry.x.values[0])
# Out:
# 126.15807367049467

# %%
#Trento - Genova
ox.bearing.calculate_bearing(trento.geometry.y.values[0],trento.geometry.x.values[0],genova.geometry.y.values[0],genova.geometry.x.values[0])
# Out:
# 223.6151117316925

# %% [markdown]
# ## Calculate isochornes

# %%
trip_times = [3, 6, 9, 15]  # in minutes
travel_speed = 4  # walking speed in km/hour
from shapely.geometry import Point

# %%
# we select the train station as center
center_node = point_nearest_train_station
center_node = point_nearest_bridge_rialto

# %%
# add an edge attribute for time in minutes required to traverse each edge
meters_per_minute = travel_speed * 1000 / 60  # km per hour to m per minute
for orig,dest, p, data in G_proj.edges(data=True, keys=True):
    data["time"] = data["length"] / meters_per_minute

# %%
# make the isochrone polygons
isochrone_polys = []
for trip_time in sorted(trip_times, reverse=True):
    subgraph = nx.ego_graph(G_proj, center_node, radius=trip_time, distance="time")
    node_points = [Point((data["x"], data["y"])) for node, data in subgraph.nodes(data=True)]
    bounding_poly = gpd.GeoSeries(node_points).unary_union.convex_hull
    isochrone_polys.append(bounding_poly)

# %%
crs_proj = ox.graph_to_gdfs(G_proj)[0].crs

# %%
data = {'trip_time': sorted(trip_times, reverse=True), 'geometry': isochrone_polys}
isochrones = gpd.GeoDataFrame(data,crs=crs_proj)

# %%
isochrones.explore(column='trip_time',cmap='Reds')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f7b4723bfcc810dc59aeaf73e5ed82c8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f7b4723bfcc810dc59aeaf73e5ed82c8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f7b4723bfcc810dc59aeaf73e5ed82c8 = L.map(
#                 &quot;map_f7b4723bfcc810dc59aeaf73e5ed82c8&quot;,
#                 {
#                     center: [45.438103749999996, 12.33615835],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f7b4723bfcc810dc59aeaf73e5ed82c8);
#
#
#
#
#
#             var tile_layer_523bfea1294d4ef89a0c77ae2f9af3ea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_523bfea1294d4ef89a0c77ae2f9af3ea.addTo(map_f7b4723bfcc810dc59aeaf73e5ed82c8);
#
#
#             map_f7b4723bfcc810dc59aeaf73e5ed82c8.fitBounds(
#                 [[45.4318125, 12.3263568], [45.444395, 12.3459599]],
#                 {}
#             );
#
#
#         function geo_json_969057cd2553b658fe71f559d0b50cb9_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#67000d&quot;, &quot;fillColor&quot;: &quot;#67000d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#fb6b4b&quot;, &quot;fillColor&quot;: &quot;#fb6b4b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#fcbca2&quot;, &quot;fillColor&quot;: &quot;#fcbca2&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#fff5f0&quot;, &quot;fillColor&quot;: &quot;#fff5f0&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_969057cd2553b658fe71f559d0b50cb9_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_969057cd2553b658fe71f559d0b50cb9_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_969057cd2553b658fe71f559d0b50cb9_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_969057cd2553b658fe71f559d0b50cb9_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_969057cd2553b658fe71f559d0b50cb9.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_969057cd2553b658fe71f559d0b50cb9_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_969057cd2553b658fe71f559d0b50cb9 = L.geoJson(null, {
#                 onEachFeature: geo_json_969057cd2553b658fe71f559d0b50cb9_onEachFeature,
#
#                 style: geo_json_969057cd2553b658fe71f559d0b50cb9_styler,
#                 pointToLayer: geo_json_969057cd2553b658fe71f559d0b50cb9_pointToLayer,
#         });
#
#         function geo_json_969057cd2553b658fe71f559d0b50cb9_add (data) {
#             geo_json_969057cd2553b658fe71f559d0b50cb9
#                 .addData(data);
#         }
#             geo_json_969057cd2553b658fe71f559d0b50c

# %% [markdown]
# ---
#
# # Use GraphHoper
#
# ![](https://www.graphhopper.com/wp-content/uploads/2018/03/graphhopper-logo-small.png)
#
# Visit [https://www.graphhopper.com/](https://www.graphhopper.com/)
#
# ## Install a local instance
# - download data from OpenStreetMap<br/>Example: Trento<br/><br/>[https://osmit-estratti.wmcloud.org/output/pbf/comuni/022205_Trento.osm.pbf](https://osmit-estratti.wmcloud.org/output/pbf/comuni/022205_Trento.osm.pbf)
# - check to have istallend java SE version 17. <pre>java --version
# java 17.0.1 2021-10-19 LTS
# Java(TM) SE Runtime Environment (build 17.0.1+12-LTS-39)
# Java HotSpot(TM) 64-Bit Server VM (build 17.0.1+12-LTS-39, mixed mode, sharing)
# </pre>
# - download the jar of grapphoper from github - [https://repo1.maven.org/maven2/com/graphhopper/graphhopper-web/9.1/graphhopper-web-9.1.jar](https://repo1.maven.org/maven2/com/graphhopper/graphhopper-web/9.1/graphhopper-web-9.1.jar)
# - create the yaml file configuration for the graphhopper with the variabile <pre>datareader.file</pre> equals to the file name you donwloaded (eg."022205_Trento.osm.pbf") and the configuration with the different profiles (eg. car, bike, foot ...).<br/>An example [here](https://raw.githubusercontent.com/napo/geospatial_datascience_unitn_2023/main/data/conf_grapphoper/config_trento.yml)
# - run the grapphoper istance<br/><pre>java -jar graphhopper*.jar server config_trento.yml</pre>
# - you can reach the service at <pre>http://localhost:8989</pre>
#
# Here a bash script to download everything<br/>
# tip: create a working directory
#
# ```bash
# wget -c https://osmit-estratti.wmcloud.org/output/pbf/comuni/022205_Trento.osm.pbf;
# wget -c https://repo1.maven.org/maven2/com/graphhopper/graphhopper-web/9.1/graphhopper-web-9.1.jar;
# wget -c https://raw.githubusercontent.com/napo/geospatial_unitn_2024/refs/heads/main/data/config/config_trento.yml;
# ```
#
#
# later run the service and ... have patience for the first run because graphhopper needs to parse the pbf file gave in input
#
#
# ```bash
# java -jar graphhopper*.jar server config_trento.yml
# ```
#
# You can use the bash script [here](https://raw.githubusercontent.com/napo/geospatial_unitn_2024/refs/heads/main/code/graphhopper_start.sh)
#
# The base URL now is: <pre>http://localhost:8989</pre>
#
# Otherwise you can use the official instance with a token api and relative [prices](https://www.graphhopper.com/pricing/)
#
# Here a list of the more important API available
#
# | end point | function | description |
# |---|---|---|
# |http://localhost:8989/| maps | web client front-end for routing |
# |http://localhost:8989/health| health | inform if the service is running |
# |http://localhost:8989/isochrone| isochrone | calculate the isochrone [here](https://docs.graphhopper.com/#tag/Isochrone-API) the documentation |
# |http://localhost:8989/match| match | map matching service in POST - [here](https://docs.graphhopper.com/#tag/Map-Matching-API) the documentation |
# |http://localhost:8989/route| routing service | documentation [here](https://docs.graphhopper.com/#tag/Routing-API)|

# %% [markdown]
# ## How to use it
# ### routing
#
# Calculate the routing from [Sanbapolis](https://www.openstreetmap.org/?mlat=46.04717&mlon=11.13261#map=18/46.04717/11.13261) to [BUC](https://www.openstreetmap.org/?mlat=46.05968&mlon=11.11552#map=19/46.05968/11.11552)
#
# Sanbapolis:
# - latitude: 46.04717
# - longitude: 11.13261
#
# BUC:
# - latitude: 46.05968
# - longitude: 11.11552
#
# Syntax in GET:
# ```
# http://localhost:8989/route?point=latitude,longitude&point=latitude,longitude
# ```

# %%
import requests

url = "http://localhost:8989/route"
url ="https://rc43wrmc78ib.share.zrok.io/route"
start_latitude = "46.04717"
start_longitude = "11.13261"
start_point = start_latitude + "," + start_longitude
end_latitude = "46.05968"
end_longitude = "11.11552"
end_point = end_latitude + "," + end_longitude

query = "?profile=car"
query += "&locale=it"
query += "&point=" +start_point
query += "&point=" +end_point

response = requests.get(url+query)

data = response.json()
print(data.keys())
# Out:
# dict_keys(['hints', 'info', 'paths'])

# %%
data['hints']
# Out:
# {'visited_nodes.sum': 53, 'visited_nodes.average': 53.0}

# %%
data['info']
# Out:
# {'copyrights': ['GraphHopper', 'OpenStreetMap contributors'],
#  'took': 5,
#  'road_data_time_stamp': '1970-01-01T00:00:00Z'}

# %%
len(data['paths'])
# Out:
# 1

# %%
data['paths'][0].keys()
# Out:
# dict_keys(['distance', 'weight', 'time', 'transfers', 'points_encoded', 'points_encoded_multiplier', 'bbox', 'points', 'instructions', 'legs', 'details', 'ascend', 'descend', 'snapped_waypoints'])

# %%
data['paths'][0]['distance'] #meters
# Out:
# 2899.593

# %%
data['paths'][0]['time'] #milliseconds
# Out:
# 264291

# %%
data['paths'][0]['points']
# Out:
# 'yq`xGyi}bAHFJBPBfHIHBFFFTFpEGNKNqABaBRUJuQo@]BUDQJWVCGKIM?EBEFCHAJ?HMBqDtB{@^_Cr@q@Hk@D}C@_A@{@LoCf@c@LcAl@qDvAy@XgAf@{GnC]FWF}@pA}@fA}BbCeGhGDf@j@jEfD`Z@F?HGTKBEHCF?LBL?X@hCBfABj@R`CFnBBz@\\F'

# %% [markdown]
# We need the polyne encoder/decoder
#
# Check here the [documentation](https://developers.google.com/maps/documentation/utilities/polylinealgorithm)

# %%
import polyline
points = polyline.decode(data['paths'][0]['points'] )

# %%
from shapely.geometry import LineString
from shapely.ops import transform
route = LineString(points)

# %%
route
# Out:
# <LINESTRING (46.047 11.133, 46.047 11.133, 46.047 11.133, 46.047 11.133, 46....>

# %%
route = transform(lambda x, y: (y, x),route)

# %%
route
# Out:
# <LINESTRING (11.133 46.047, 11.133 46.047, 11.133 46.047, 11.133 46.047, 11....>

# %%
routing_result = gpd.GeoDataFrame(
    [{"time": data['paths'][0]['time'],"geometry": route, "distance":data['paths'][0]['distance']}],
    crs="epsg:4326",
    geometry="geometry")

# %%
routing_result.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b757f59806c44625fb086699285fb7a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b757f59806c44625fb086699285fb7a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b757f59806c44625fb086699285fb7a = L.map(
#                 &quot;map_1b757f59806c44625fb086699285fb7a&quot;,
#                 {
#                     center: [46.053129999999996, 11.124265],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_1b757f59806c44625fb086699285fb7a);
#
#
#
#
#
#             var tile_layer_28c09fd53b7b2607de15bb7311cd05ef = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_28c09fd53b7b2607de15bb7311cd05ef.addTo(map_1b757f59806c44625fb086699285fb7a);
#
#
#             map_1b757f59806c44625fb086699285fb7a.fitBounds(
#                 [[46.04532, 11.11592], [46.06094, 11.13261]],
#                 {}
#             );
#
#
#         function geo_json_f8a6ef793bf4f21f3be4a9a8104da0b2_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_f8a6ef793bf4f21f3be4a9a8104da0b2_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_f8a6ef793bf4f21f3be4a9a8104da0b2_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_f8a6ef793bf4f21f3be4a9a8104da0b2_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_f8a6ef793bf4f21f3be4a9a8104da0b2_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_f8a6ef793bf4f21f3be4a9a8104da0b2.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_f8a6ef793bf4f21f3be4a9a8104da0b2_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_f8a6ef793bf4f21f3be4a9a8104da0b2 = L.geoJson(null, {
#                 onEachFeature: geo_json_f8a6ef793bf4f21f3be4a9a8104da0b2_onEachFeature,
#
#                 style: geo_json_f8a6ef793bf4f21f3be4a9a8104da0b2_styler,
#                 pointToLayer: geo_json_f8a6ef793bf4f21f3be4a9a8104da0b2_pointToLayer,
#         });
#
#         function geo_json_f8a6ef793bf4f21f3be4a9a8104da0b2_add (data) {
#             geo_json_f8a6ef793bf4f21f3be4a9a8104da0b2
#                 .addData(data);
#         }
#             geo_json_f8a6ef793bf4f21f3be4a9a8104da0b2_add({&quot;bbox&quot;: [11.11592, 46.04532, 11.13261, 46.06094], &quot;features&quot;: [{&quot;bbox&quot;: [11.11592, 46.04532, 11.13261, 46.06094], &quot;geometry&quot;: {&quot;coordinates&quot;: [[11.13261, 46.04717], [11.13257, 46.04712], [11.13255, 46.04706], [11.13253, 46.04697], [11.13258, 46.04549], [11.13256, 46.04544], [11.13252, 46.0454], [11.13241, 46.04536], [11.13136, 46.04532], [11.13128, 46.04536], [11.1312, 46.04542], [11.13118, 46.04583], [11.13108, 46.04632], [11.13102, 46.04643], [11.13126, 46.04942], [11.13124, 46.04957], [11.13121, 46.04968], [11.13115, 46.04977], [11.13103, 46.04989], [11.13107, 46.04991], [11.13112, 46.04997], [11.13112, 46.05004], [11.1311, 46.05007], [11.13106, 46.0501], [11.13101, 46.05012], [11.13095, 46.05013], [11.1309, 46.05013], [11.13088, 46.0502],

# %% [markdown]
# #### and by foot

# %%
query = "?profile=foot"
query += "&locale=it"
query += "&point=" +start_point
query += "&point=" +end_point
query += "&ch.disable=true"
response = requests.get(url+query)
data = response.json()
points = polyline.decode(data['paths'][0]['points'])
route = transform(lambda x, y: (y, x),LineString(points))
routing_result = gpd.GeoDataFrame(
    [{"time": data['paths'][0]['time'],"geometry": route, "distance":data['paths'][0]['distance']}],
    crs="epsg:4326",
    geometry="geometry")
routing_result.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab47d59f7a73f46a3d7b9972275bc249 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab47d59f7a73f46a3d7b9972275bc249&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab47d59f7a73f46a3d7b9972275bc249 = L.map(
#                 &quot;map_ab47d59f7a73f46a3d7b9972275bc249&quot;,
#                 {
#                     center: [46.05404, 11.12407],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_ab47d59f7a73f46a3d7b9972275bc249);
#
#
#
#
#
#             var tile_layer_03034f068a22bd99cb45933d0e1f5ddb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_03034f068a22bd99cb45933d0e1f5ddb.addTo(map_ab47d59f7a73f46a3d7b9972275bc249);
#
#
#             map_ab47d59f7a73f46a3d7b9972275bc249.fitBounds(
#                 [[46.04717, 11.11552], [46.06091, 11.13262]],
#                 {}
#             );
#
#
#         function geo_json_c1efd970cb160dec75c8635572309528_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_c1efd970cb160dec75c8635572309528_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_c1efd970cb160dec75c8635572309528_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_c1efd970cb160dec75c8635572309528_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_c1efd970cb160dec75c8635572309528_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_c1efd970cb160dec75c8635572309528.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_c1efd970cb160dec75c8635572309528_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_c1efd970cb160dec75c8635572309528 = L.geoJson(null, {
#                 onEachFeature: geo_json_c1efd970cb160dec75c8635572309528_onEachFeature,
#
#                 style: geo_json_c1efd970cb160dec75c8635572309528_styler,
#                 pointToLayer: geo_json_c1efd970cb160dec75c8635572309528_pointToLayer,
#         });
#
#         function geo_json_c1efd970cb160dec75c8635572309528_add (data) {
#             geo_json_c1efd970cb160dec75c8635572309528
#                 .addData(data);
#         }
#             geo_json_c1efd970cb160dec75c8635572309528_add({&quot;bbox&quot;: [11.11552, 46.04717, 11.13262, 46.06091], &quot;features&quot;: [{&quot;bbox&quot;: [11.11552, 46.04717, 11.13262, 46.06091], &quot;geometry&quot;: {&quot;coordinates&quot;: [[11.13261, 46.04717], [11.13262, 46.04718], [11.13252, 46.0473], [11.1324, 46.04747], [11.13214, 46.04794], [11.13201, 46.04806], [11.13182, 46.04814], [11.13166, 46.04825], [11.13158, 46.04836], [11.13146, 46.04864], [11.1313, 46.0488], [11.13128, 46.04881], [11.13129, 46.04894], [11.13131, 46.04901], [11.13134, 46.04938], [11.13133, 46.04957], [11.13129, 46.0497], [11.1312, 46.04994], [11.13121, 46.04997], [11.13123, 46.04998], [11.13129, 46.05], [11.13127, 46.0501], [11.13115, 46.05011], [11.13109, 46.05015], [11.13098, 46.05019], [11.13082, 46.05041], [11.13052, 46.05084], [11.13049, 46.05103], [11.13043, 46.

# %%
data
# Out:
# {'hints': {'visited_nodes.sum': 1796, 'visited_nodes.average': 1796.0},
#  'info': {'copyrights': ['GraphHopper', 'OpenStreetMap contributors'],
#   'took': 6,
#   'road_data_time_stamp': '1970-01-01T00:00:00Z'},
#  'paths': [{'distance': 2486.423,
#    'weight': 1496.538184,
#    'time': 1790229,
#    'transfers': 0,
#    'points_encoded': True,
#    'points_encoded_multiplier': 100000.0,
#    'bbox': [11.11552, 46.047169, 11.132622, 46.060907],
#    'points': 'yq`xGyi}bAAAWRa@V}Ar@WXOd@U^UNw@V_@^ABYAMCiAEe@@YFo@PEAACCKSBAVGJGTk@^uAz@e@DQJe@GKt@}@Zy@TYDmAJGC}@@E@o@BGCUAABC??Vq@@M@aANmCd@YJYLk@^wBz@iBt@QNu@ZI@SFkHzCOHi@l@ILMJC@Y^gAlAyAzAAFAPOAAPGRQCC?wDbEIH?B?NG@j@jEfD`Z@F?HGTKBEHCF?LBL?XD@HLABCRFdDTjDD~@Br@BXDNJDE^G@CDB|@',
#    'instructions': [{'distance': 1.54,
#      'heading': 29.96,
#      'sign': 0,
#      'interval': [0, 1],
#      'text': 'Continua su Via della Malpensada',
#      'time': 1108,
#      'street_name': 'Via della Malpensada'},
#     {'distance': 212.936,
#      'sign': -2,
#      'interval': [1, 11],
#      'text': 'Gira a sinistra su Via della Malpensada',
#      'time': 153314,
#      'street_name': 'Via della Malpensada'},
#     {'distance': 137.594,
#      'sign': 2,
#      'interval': [11, 20],
#      'text': 'Gira a destra',
#      'time': 99068,
#      'street_name': ''},
#     {'distance': 406.363,
#      'sign': -2,
#      'interval': [20, 40],
#      'text': 'Gira a sinistra',
#      'time': 292582,
#      'street_name': ''},
#     {'distance': 4.217,
#      'sign': -2,
#      'interval': [40, 42],
#      'text': 'Gira a sinistra',
#      'time': 3036,
#      'street_name': ''},
#     {'distance': 8.775,
#      'sign': -2,
#      'interval': [42, 43],
#      'text': 'Gira a sinistra',
#      'time': 6318,
#      'street_name': ''},
#     {'distance': 281.684,
#      'sign': 2,
#      'interval': [43, 51],
#      'text': 'Gira a destra',
#      'time': 202812,
#      'street_name': ''},
#     {'distance': 499.801,
#      'sign': 0,
#      'interval': [51, 67],
#      'text': 'Continua',
#      'time': 359857,
#      'street_name': ''},
#     {'distance': 9.335,
#      'sign': 2,
#      'interval': [67, 68],
#      'text': 'Gira a destra',
#      'time': 6721,
#      'street_name': ''},
#     {'distance': 16.422,
#      'sign': -2,
#      'interval': [68, 70],
#      'text': 'Gira a sinistra',
#      'time': 11824,
#      'street_name': ''},
#     {'distance': 138.89,
#      'sign': 2,
#      'interval': [70, 73],
#      'text': 'Gira a destra',
#      'time': 100001,
#      'street_name': ''},
#     {'distance': 14.201,
#      'sign': 0,
#      'interval': [73, 76],
#      'text': 'Continua',
#      'time': 10225,
#      'street_name': ''},
#     {'distance': 4.503,
#      'sign': 2,
#      'interval': [76, 77],
#      'text': 'Gira a destra',
#      'time': 3242,
#      'street_name': ''},
#     {'distance': 445.205,
#      'sign': -2,
#      'interval': [77, 82],
#      'text': 'Gira a sinistra su Via Fratelli Perini',
#      'time': 320549,
#      'street_name': 'Via Fratelli Perini'},
#     {'exit_number': 3,
#      'distance': 37.496,
#      'sign': 6,
#      'exited': True,
#      'turn_angle': -3.5,
#      'interval': [82, 88],
#      'text': "Nella rotatoria, prendere l'uscita 3 su Via Anna Maestri",
#      'time': 26997,
#      'street_name': 'Via Anna Maestri'},
#     {'distance': 11.731,
#      'sign': -2,
#      'interval': [88, 90],
#      'text': 'Gira a sinistra',
#      'time': 8448,
#      'street_name': ''},
#     {'distance': 223.488,
#      'sign': 2,
#      'interval': [90, 100],
#      'text': 'Gira a destra',
#      'time': 160912,
#      'street_name': ''},
#     {'distance': 4.997,
#      'sign': 2,
#      'interval': [100, 101],
#      'text': 'Gira a destra',
#      'time': 3598,
#      'street_name': ''},
#     {'distance': 27.246,
#      'sign': -2,
#      'interval': [101, 103],
#      'text': 'Gira a sinistra',
#      'time': 19617,
#      'street_name': ''},
#     {'distance': 0.0,
#      'sign': 4,
#      'last_heading': 264.3799154072158,
#      'interval': [103, 103],
#      'text': 'Arrivato a destinazione',
#      'time': 0,
#      'street_name': ''}],
#    'legs': [],
#    'details': {},
#    'ascend': 0.0,
#    'descend': 0.0,
#    'snapped_waypoints': 'yq`xGyi}bAemAxiB'}]}

# %% [markdown]
# ### ischrone
#
# Calculate a isochrone of 5 minutes of [Sanbapolis](https://www.openstreetmap.org/?mlat=46.04717&mlon=11.13261#map=18/46.04717/11.13261)
#
# Sanbapolis:
# - latitude: 46.04717
# - longitude: 11.13261
# Syntax in GET:
# ```
# http://localhost:8989/isochrone?point=latitude,longitude&time_limit=timeseconds&distance_limit=distance&profile=foot&bucket=1&reverse_flow=false
# ```

# %%
url = "http://localhost:8989/isochrone"
url ="https://rc43wrmc78ib.share.zrok.io/isochrone"
lat = "46.04717"
lon = "11.13261"
minutes_distance = 5
timeseconds = str(minutes_distance*60)
p = lon + "," + lat
query = {
  "point": lat + "," + lon,
  "time_limit": timeseconds,
  "distance_limit": "0",
  "profile": "foot",
  "buckets": "1",
  "reverse_flow": "false"}
response = requests.get(url, params=query)
data = response.json()

# %%
from shapely.geometry import Polygon
geometry = Polygon(data['polygons'][0]['geometry']['coordinates'][0])

# %%
isochrone = gpd.GeoDataFrame(
    [{"minutes_distance":minutes_distance,"geometry": geometry}],
    crs="epsg:4326",
    geometry="geometry")

# %%
isochrone.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bfaa2e9d871cfd6c97b6c155c719bf3f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bfaa2e9d871cfd6c97b6c155c719bf3f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bfaa2e9d871cfd6c97b6c155c719bf3f = L.map(
#                 &quot;map_bfaa2e9d871cfd6c97b6c155c719bf3f&quot;,
#                 {
#                     center: [46.04708855, 11.132909025],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_bfaa2e9d871cfd6c97b6c155c719bf3f);
#
#
#
#
#
#             var tile_layer_7ba29e3828f0fda51df61830f0223ce8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7ba29e3828f0fda51df61830f0223ce8.addTo(map_bfaa2e9d871cfd6c97b6c155c719bf3f);
#
#
#             map_bfaa2e9d871cfd6c97b6c155c719bf3f.fitBounds(
#                 [[46.043357900000004, 11.13000605], [46.0508192, 11.135812000000001]],
#                 {}
#             );
#
#
#         function geo_json_dc135a409fb390e5d5ccefe7dc5d6fb6_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_dc135a409fb390e5d5ccefe7dc5d6fb6_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_dc135a409fb390e5d5ccefe7dc5d6fb6_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_dc135a409fb390e5d5ccefe7dc5d6fb6_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_dc135a409fb390e5d5ccefe7dc5d6fb6_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_dc135a409fb390e5d5ccefe7dc5d6fb6.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_dc135a409fb390e5d5ccefe7dc5d6fb6_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_dc135a409fb390e5d5ccefe7dc5d6fb6 = L.geoJson(null, {
#                 onEachFeature: geo_json_dc135a409fb390e5d5ccefe7dc5d6fb6_onEachFeature,
#
#                 style: geo_json_dc135a409fb390e5d5ccefe7dc5d6fb6_styler,
#                 pointToLayer: geo_json_dc135a409fb390e5d5ccefe7dc5d6fb6_pointToLayer,
#         });
#
#         function geo_json_dc135a409fb390e5d5ccefe7dc5d6fb6_add (data) {
#             geo_json_dc135a409fb390e5d5ccefe7dc5d6fb6
#                 .addData(data);
#         }
#             geo_json_dc135a409fb390e5d5ccefe7dc5d6fb6_add({&quot;bbox&quot;: [11.13000605, 46.043357900000004, 11.135812000000001, 46.0508192], &quot;features&quot;: [{&quot;bbox&quot;: [11.13000605, 46.043357900000004, 11.135812000000001, 46.0508192], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[11.135778049999999, 46.04760585], [11.13579175, 46.047753799999995], [11.13554615, 46.048870050000005], [11.1355438, 46.0489207], [11.1350822, 46.04918240000001], [11.13497675, 46.0494046], [11.134954400000002, 46.04950715], [11.13467455, 46.049953599999995], [11.134639100000001, 46.050355100000004], [11.1346025, 46.05038375], [11.133726, 46.050802250000004], [11.13367805, 46.0508192], [11.13344045, 46.05049855], [11.13335015, 46.05012695], [11.1337431, 46.0500327], [11.133751499999999, 46.05010645], [11.13379945, 46.0500895], [11

# %% [markdown]
# ### Istodistance
# ... and in 300 meters

# %%
distance = 300
p = lon + "," + lat
query = {
  "point": lat + "," + lon,
  "time_limit": 0,
  "distance_limit":distance,
  "profile": "foot",
  "buckets": "1",
  "reverse_flow": "false"}
response = requests.get(url, params=query)
data = response.json()

# %%
geometry = Polygon(data['polygons'][0]['geometry']['coordinates'][0])
isodistance = gpd.GeoDataFrame(
    [{"minutes_distance":minutes_distance,"geometry": geometry}],
    crs="epsg:4326",
    geometry="geometry")
isodistance.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f69e3a5dccae4d7b397704488e2b1f7f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f69e3a5dccae4d7b397704488e2b1f7f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f69e3a5dccae4d7b397704488e2b1f7f = L.map(
#                 &quot;map_f69e3a5dccae4d7b397704488e2b1f7f&quot;,
#                 {
#                     center: [46.047191999999995, 11.13328455],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f69e3a5dccae4d7b397704488e2b1f7f);
#
#
#
#
#
#             var tile_layer_192926083b76f1a10e82c951d05800a4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_192926083b76f1a10e82c951d05800a4.addTo(map_f69e3a5dccae4d7b397704488e2b1f7f);
#
#
#             map_f69e3a5dccae4d7b397704488e2b1f7f.fitBounds(
#                 [[46.04470164999999, 11.1307571], [46.04968235, 11.135812000000001]],
#                 {}
#             );
#
#
#         function geo_json_a5bbf063ee47d488565706787ae0091e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_a5bbf063ee47d488565706787ae0091e_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_a5bbf063ee47d488565706787ae0091e_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_a5bbf063ee47d488565706787ae0091e_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_a5bbf063ee47d488565706787ae0091e_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_a5bbf063ee47d488565706787ae0091e.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_a5bbf063ee47d488565706787ae0091e_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_a5bbf063ee47d488565706787ae0091e = L.geoJson(null, {
#                 onEachFeature: geo_json_a5bbf063ee47d488565706787ae0091e_onEachFeature,
#
#                 style: geo_json_a5bbf063ee47d488565706787ae0091e_styler,
#                 pointToLayer: geo_json_a5bbf063ee47d488565706787ae0091e_pointToLayer,
#         });
#
#         function geo_json_a5bbf063ee47d488565706787ae0091e_add (data) {
#             geo_json_a5bbf063ee47d488565706787ae0091e
#                 .addData(data);
#         }
#             geo_json_a5bbf063ee47d488565706787ae0091e_add({&quot;bbox&quot;: [11.1307571, 46.04470164999999, 11.135812000000001, 46.04968235], &quot;features&quot;: [{&quot;bbox&quot;: [11.1307571, 46.04470164999999, 11.135812000000001, 46.04968235], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[11.1315551, 46.0480116], [11.1318307, 46.04780385], [11.13194275, 46.04772745], [11.1321362, 46.0477756], [11.132214999999999, 46.0476296], [11.1322665, 46.04754255], [11.13218705, 46.04742345], [11.132291649999999, 46.047276800000006], [11.13233275, 46.04717805], [11.132334499999999, 46.04702615], [11.1323462, 46.046746600000006], [11.1322443, 46.0467149], [11.132139800000001, 46.0465498], [11.1321433, 46.0464685], [11.13215595, 46.046110049999996], [11.13217495, 46.04558555], [11.13205485, 46.045435499999996], [11.13186275, 4

# %% [markdown]
# ## Map Matching
#
# ![](https://fmm-wiki.github.io/assets/images/demo2.gif)
#
# Read the documentation of [Fast Map Matching](https://fmm-wiki.github.io/)

# %% [markdown]
# An example
#
# ![](https://raw.githubusercontent.com/napo/geospatial_unitn_2024/refs/heads/main/images/journey_trento_downtown.png)
#
# [Download](https://gist.githubusercontent.com/napo/fc93af265b3d4a00e30be0bfc0e7ec06/raw/9fd6bc2a48538a3d4fad8789dd0315ca7f81fa8a/journey_trento_downtown.gpx)
#
# http://localhost:8989/maps/map-matching/

# %%
import requests
headers = {
    'content-type': 'application/gpx+xml',
}
gpx_url = "https://gist.githubusercontent.com/napo/fc93af265b3d4a00e30be0bfc0e7ec06/raw/9fd6bc2a48538a3d4fad8789dd0315ca7f81fa8a/journey_trento_downtown.gpx"
response = requests.get(gpx_url)
gpx_str = response.content
url = 'http://localhost:8989/match'
url = "https://rc43wrmc78ib.share.zrok.io/match"
params = {
    'profile': 'foot',
    'gps_accuracy': '10',
    'type': 'json'
}
response = requests.post(url, headers=headers, params=params, data=gpx_str,verify=False)
data = response.json()

# %%
data.keys()
# Out:
# dict_keys(['hints', 'info', 'paths', 'map_matching'])

# %%
data['map_matching']
# Out:
# {'original_distance': 1342.374625154211,
#  'distance': 1371.394148332895,
#  'time': 987407}

# %%
len(data['paths'])
# Out:
# 1

# %%
data['paths'][0].keys()
# Out:
# dict_keys(['distance', 'weight', 'time', 'transfers', 'points_encoded', 'points_encoded_multiplier', 'bbox', 'points', 'instructions', 'legs', 'details', 'ascend', 'descend', 'snapped_waypoints'])

# %%
points = polyline.decode(data['paths'][0]['points'] )

# %%
route = LineString(points)
route = transform(lambda x, y: (y, x),route)
routing_result = gpd.GeoDataFrame(
    [{"time": data['paths'][0]['time'],"geometry": route, "distance":data['paths'][0]['distance']}],
    crs="epsg:4326",
    geometry="geometry")
routing_result.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94fe96f394f1c8a1ad62661e105b00e8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94fe96f394f1c8a1ad62661e105b00e8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_94fe96f394f1c8a1ad62661e105b00e8 = L.map(
#                 &quot;map_94fe96f394f1c8a1ad62661e105b00e8&quot;,
#                 {
#                     center: [46.06758, 11.123835],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_94fe96f394f1c8a1ad62661e105b00e8);
#
#
#
#
#
#             var tile_layer_eaf33ee00fb86170f32513880194dfff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_eaf33ee00fb86170f32513880194dfff.addTo(map_94fe96f394f1c8a1ad62661e105b00e8);
#
#
#             map_94fe96f394f1c8a1ad62661e105b00e8.fitBounds(
#                 [[46.0652, 11.11955], [46.06996, 11.12812]],
#                 {}
#             );
#
#
#         function geo_json_bc199556322e33362b7094f6f9fe4c0b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_bc199556322e33362b7094f6f9fe4c0b_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_bc199556322e33362b7094f6f9fe4c0b_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_bc199556322e33362b7094f6f9fe4c0b_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_bc199556322e33362b7094f6f9fe4c0b_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_bc199556322e33362b7094f6f9fe4c0b.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_bc199556322e33362b7094f6f9fe4c0b_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_bc199556322e33362b7094f6f9fe4c0b = L.geoJson(null, {
#                 onEachFeature: geo_json_bc199556322e33362b7094f6f9fe4c0b_onEachFeature,
#
#                 style: geo_json_bc199556322e33362b7094f6f9fe4c0b_styler,
#                 pointToLayer: geo_json_bc199556322e33362b7094f6f9fe4c0b_pointToLayer,
#         });
#
#         function geo_json_bc199556322e33362b7094f6f9fe4c0b_add (data) {
#             geo_json_bc199556322e33362b7094f6f9fe4c0b
#                 .addData(data);
#         }
#             geo_json_bc199556322e33362b7094f6f9fe4c0b_add({&quot;bbox&quot;: [11.11955, 46.0652, 11.12812, 46.06996], &quot;features&quot;: [{&quot;bbox&quot;: [11.11955, 46.0652, 11.12812, 46.06996], &quot;geometry&quot;: {&quot;coordinates&quot;: [[11.11955, 46.06671], [11.12019, 46.06677], [11.12036, 46.06603], [11.12105, 46.0661], [11.12106, 46.06604], [11.12109, 46.06605], [11.12109, 46.06571], [11.1211, 46.06557], [11.12122, 46.06553], [11.12122, 46.06547], [11.12289, 46.0652], [11.12316, 46.06524], [11.1231, 46.06537], [11.12306, 46.06553], [11.12269, 46.06624], [11.12259, 46.06628], [11.12241, 46.06651], [11.12229, 46.06678], [11.12332, 46.06692], [11.12329, 46.06696], [11.1232, 46.06728], [11.12326, 46.06728], [11.12326, 46.06732], [11.12376, 46.06735], [11.12378, 46.06736], [11.12406, 46.06738], [11.12403, 46.06752], [11.12403, 46.0676], [11.12389, 4

# %% [markdown]
# ---
#
# # GNSS
#
#  Global Navigation Satellite System (GNSS) refers to a constellation of satellites providing signals from space that transmit positioning and timing data to GNSS receivers. The receivers then use this data to determine location. By definition, GNSS provides global coverage.
#
# ## basic
# ![](https://ardupilot.org/copter/_images/ag_GPS_Operation_New_low_res.jpg)
#
# ## with corrections
# ![](https://freesvg.org/img/GPS_differentialCorrection.png)
#
# ---

# %% [markdown]
# # GPX Format
# GPX, or GPS Exchange Format, is an XML schema designed as a common GPS data format for software applications. It can be used to describe waypoints, tracks, and routes.
#
# ## units
# ### position
# latitude and longitude are expressed in **decimal degrees**, and **elevation in meters**, both using the **WGS 84 datum** (epsg 4326).
# ### time
# dates and times are not local time, but instead are Coordinated Universal Time (UTC) using ISO 8601 format (YYYY-MM-DDTHH:MM:SSZ)
#
#
# ## data
#
# ![](https://upload.wikimedia.org/wikipedia/commons/a/a2/Wayroutrackp.png)
#
# (image by [Berklas](https://commons.wikimedia.org/w/index.php?title=User:Berklas) distributed under cc-by-sa 3.0)
#
# - **wptType** is an individual waypoint among a collection of points with no sequential relationship. It consists of the WGS 84 (GPS) coordinates of a point and possibly other descriptive information.
# - **rteType** is a route, an ordered list of routepoint (waypoints representing a series of significant turn or stage points) leading to a destination.
# - **trkType** is a track, made of at least one segment containing waypoints, that is, an ordered list of points describing a path. A Track Segment holds a list of Track Points which are logically connected in order. To represent a single GPS track where GPS reception was lost, or the GPS receiver was turned off, start a new Track Segment for each continuous span of track data.
#
#
# details about the format on fhe officiale [website](https://www.topografix.com/gpx.asp)
#
#
# ```xml
# <?xml version="1.0" encoding="UTF-8" standalone="no" ?>
# <gpx xmlns="http://www.topografix.com/GPX/1/1" xmlns:gpxx="http://www.garmin.com/xmlschemas/GpxExtensions/v3" xmlns:gpxtpx="http://www.garmin.com/xmlschemas/TrackPointExtension/v1" creator="Oregon 400t" version="1.1" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.topografix.com/GPX/1/1 http://www.topografix.com/GPX/1/1/gpx.xsd http://www.garmin.com/xmlschemas/GpxExtensions/v3 http://www.garmin.com/xmlschemas/GpxExtensionsv3.xsd http://www.garmin.com/xmlschemas/TrackPointExtension/v1 http://www.garmin.com/xmlschemas/TrackPointExtensionv1.xsd">
#   <metadata>
#     <link href="http://www.garmin.com">
#       <text>Garmin International</text>
#     </link>
#     <time>2009-10-17T22:58:43Z</time>
#   </metadata>
#   <trk>
#     <name>Example GPX Document</name>
#     <trkseg>
#       <trkpt lat="47.644548" lon="-122.326897">
#         <ele>4.46</ele>
#         <time>2009-10-17T18:37:26Z</time>
#       </trkpt>
#       <trkpt lat="47.644548" lon="-122.326897">
#         <ele>4.94</ele>
#         <time>2009-10-17T18:37:31Z</time>
#       </trkpt>
#       <trkpt lat="47.644548" lon="-122.326897">
#         <ele>6.87</ele>
#         <time>2009-10-17T18:37:34Z</time>
#       </trkpt>
#     </trkseg>
#   </trk>
# </gpx>
# ```
#
# information from [wikipedia](https://en.wikipedia.org/wiki/GPS_Exchange_Format)

# %% [markdown]
# ---
#
# # Commmon problems
#
# Missing Data
# - Temporal gaps
# - Spatial gaps
#
# Incorrect data:
# - location or time is incorrect in the data frame
#
# Outliers:
# - Too fast movements
# - Incorrect order of temporal information
#
#
# ## A funny story
#
# Channon Perry and her boyfriend [analysed](https://chan.co.za/how-fateful) their personal GPS traces to find ‘missed potential fateful encounters’ in the past.
#
#
# ---

# %% [markdown]
# ## Playing with GPX

# %%
import gpxpy
import urllib.request
from datetime import datetime,timedelta
import hvplot
import geoviews
import movingpandas as mpd
import matplotlib.pyplot as plt
from shapely.geometry import Point
import warnings
warnings.filterwarnings('ignore') # ignore warnings

# %% [markdown]
# ## Download the data
#
#
# ![](https://github.com/napo/geospatial_course_unitn/blob/master/images/strava_clean.jpg?raw=true)
#
# If you are registered and the author permits the download you can download the gps track but and investigate with [GPX Studio](https://gpx.studio) **without timestamps**
#
#
# ![gpx-strava.png](https://i.postimg.cc/x8mMQL9C/gpx-strava.png)]
#
# [download file](https://gist.github.com/napo/2aa15957b687dd676d448888619bd39f)
#
# or ... you can use [Strava To Gpx](https://mapstogpx.com/strava/)
#
#
# ![gpx-full.png](https://i.postimg.cc/yNrLYXCX/gpx-full.png)]
#
# [download file](https://gist.github.com/napo/4d0c14585da0ef96f263faa0e8d97ff5)

# %%
gpx_url = "https://gist.githubusercontent.com/napo/4d0c14585da0ef96f263faa0e8d97ff5/raw/efba18f806459b462a1e485023cdd01c4d20e01a/strava_full.gpx"
gpx_file = "strava_full.gpx"
urllib.request.urlretrieve(gpx_url,gpx_file)
gpx_file = open(gpx_file, 'r')
gpx = gpxpy.parse(gpx_file)

# %%
gpx.creator
# Out:
# 'https://www.mapstogpx.com/strava'

# %%
len(gpx.tracks)
# Out:
# 1

# %%
len(gpx.tracks[0].segments)
# Out:
# 1

# %%
segment = gpx.tracks[0].segments[0]

# %%
segment
# Out:
# GPXTrackSegment(points=[...])

# %%
type(segment.points)
# Out:
# list

# %%
segment.points[0].latitude
# Out:
# 45.900222

# %%
segment.points[0].longitude
# Out:
# 10.847826

# %%
segment.points[0].elevation
# Out:
# 96.5

# %% [markdown]
# ## creation of a pandas DataFrame

# %%
import movingpandas as mpd
import pandas as pd
data = []
for point_idx, point in enumerate(segment.points):
    data.append([point.longitude, point.latitude,
                point.elevation, point.time])

columns = ['longitude', 'latitude', 'altitude', 'time']
gpx_tracks = pd.DataFrame(data, columns=columns)
# Strava to GPX assign the date of the download of the file as timestamp and SimpleTZ("Z") as TimeZone.
# we can remove it
gpx_tracks['time'] = gpx_tracks['time'].apply(lambda x: x.replace(tzinfo=None))

# index creation needed by MovingPandas
df = gpx_tracks.set_index('time')

# %%
start_point = data[0]
end_point = data[-1]
# travel time
# steps to calcolate the difference of time from the timestamp in the first point to the last.
travel_time = end_point[3]-start_point[3]
travel_time_seconds = timedelta(seconds=travel_time.total_seconds())
travel_time_hours = str(timedelta(seconds=travel_time_seconds.seconds))
print_travel_time = travel_time_hours.split(':')
print("travel time %sh %s' %s''" % (print_travel_time[0], print_travel_time[1], print_travel_time[2]))
# Out:
# travel time 2h 34' 41''

# %% [markdown]
# ## reverse geocoding

# %%
from geopy.geocoders import Nominatim

latlon = str(start_point[1]) + "," + str(start_point[0])
geolocator = Nominatim(user_agent="geospatial course unitn")
starting_place = geolocator.reverse(latlon)

# %%
starting_place
# Out:
# Location(28c, Via Luigi Pigarelli, Pasina, Varone, Riva del Garda, Comunità Alto Garda e Ledro, Provincia di Trento, Trentino-Alto Adige/Südtirol, 38066, Italia, (45.8999431, 10.8472436, 0.0))

# %%
latlon = str(end_point[1]) + "," + str(end_point[0])
geolocator = Nominatim(user_agent="geospatial course unitn")
arrival_place = geolocator.reverse(latlon)

# %%
arrival_place
# Out:
# Location(Pronto Soccorso Ospedale di Arco, Viale dei Capitelli, Chiarano, Arco, Comunità Alto Garda e Ledro, Provincia di Trento, Trentino-Alto Adige/Südtirol, 38062, Italia, (45.919077, 10.875114, 0.0))

# %% [markdown]
# ##  Analyzing trajectories

# %%
# GeoDataFrame for MovingPandas
geo_df = gpd.GeoDataFrame(df,
crs=4326,
geometry= gpd.points_from_xy(df.longitude, df.latitude, df.altitude))

# %%
geo_df.plot()
plt.show()

# %%
trajectory = mpd.Trajectory(geo_df, 0)

# %%
trajectory
# Out:
# Trajectory 0 (2021-10-12 12:01:38 to 2021-10-12 14:36:19) | Size: 5532 | Length: 40316.6m
# Bounds: (10.731099, 45.861882, 10.875513, 45.919142)
# LINESTRING Z (10.847826 45.900222 96.5, 10.84785 45.900264 96.5, 10.847843 45.900125 96.5, 10.847836

# %%
# object trajectory from MovingPandas
trajectory = mpd.Trajectory(geo_df, 1)

# %%
trajectory.plot()
plt.show()

# %%
trajectory.add_speed(overwrite=True)
trajectory.df
# Out:
#                      longitude   latitude  altitude  \
# time
# 2021-10-12 12:01:38  10.847826  45.900222      96.5
# 2021-10-12 12:01:39  10.847850  45.900264      96.5
# 2021-10-12 12:01:40  10.847843  45.900125      96.5
# 2021-10-12 12:01:41  10.847836  45.899890      96.5
# 2021-10-12 12:01:42  10.847835  45.899786      96.5
# ...                        ...        ...       ...
# 2021-10-12 14:34:13  10.875184  45.919097      91.6
# 2021-10-12 14:34:20  10.875213  45.919122      91.6
# 2021-10-12 14:34:30  10.875186  45.919142      91.6
# 2021-10-12 14:35:45  10.875151  45.919126      91.6
# 2021-10-12 14:36:19  10.875091  45.919049      91.6
#
#                                                  geometry  traj_id      speed
# time
# 2021-10-12 12:01:38  POINT Z (10.84783 45.90022 96.50000)        1   5.026084
# 2021-10-12 12:01:39  POINT Z (10.84785 45.90026 96.50000)        1   5.026084
# 2021-10-12 12:01:40  POINT Z (10.84784 45.90013 96.50000)        1  15.459309
# 2021-10-12 12:01:41  POINT Z (10.84784 45.89989 96.50000)        1  26.125749
# 2021-10-12 12:01:42  POINT Z (10.84783 45.89979 96.50000)        1  11.559794
# ...                                                   ...      ...        ...
# 2021-10-12 14:34:13  POINT Z (10.87518 45.91910 91.60000)        1   0.765202
# 2021-10-12 14:34:20  POINT Z (10.87521 45.91912 91.60000)        1   0.510754
# 2021-10-12 14:34:30  POINT Z (10.87519 45.91914 91.60000)        1   0.305432
# 2021-10-12 14:35:45  POINT Z (10.87515 45.91913 91.60000)        1   0.043276
# 2021-10-12 14:36:19  POINT Z (10.87509 45.91905 91.60000)        1   0.286540
#
# [5532 rows x 6 columns]

# %%
# conversion m/s to km/h
def ms_to_km(ms):
    v = (ms) * (60*60)/1000
    return v

# %%
# km/h column
trajectory.df['kmh'] = trajectory.df['speed'].apply(ms_to_km)

# %%
trajectory.plot(column="kmh", linewidth=5, capstyle='round', legend=True)
plt.show()

# %% [markdown]
# ## Extracting a moving object's position was at a certain time

# %%
trajectory
# Out:
# Trajectory 1 (2021-10-12 12:01:38 to 2021-10-12 14:36:19) | Size: 5532 | Length: 40316.6m
# Bounds: (10.731099, 45.861882, 10.875513, 45.919142)
# LINESTRING Z (10.847826 45.900222 96.5, 10.84785 45.900264 96.5, 10.847843 45.900125 96.5, 10.847836

# %%
trajectory.get_position_at(datetime(2021,10,12,12,6,0), method="nearest")
# Out:
# <POINT Z (10.841 45.889 81.1)>

# %%
print(trajectory.get_position_at(datetime(2021,10,12,12,6,0), method="nearest"))
# Out:
# POINT Z (10.840998 45.888594 81.1)

# %%
print(trajectory.get_position_at(datetime(2021,10,12,12,6,0), method="nearest"))
print(trajectory.get_position_at(datetime(2021,10,12,12,6,0), method="interpolated"))
print(trajectory.get_position_at(datetime(2021,10,12,12,6,0), method="ffill")) # from the previous row
print(trajectory.get_position_at(datetime(2021,10,12,12,6,0), method="bfill")) # from the following row
# Out:
# POINT Z (10.840998 45.888594 81.1)
# POINT Z (10.840998 45.888594 81.1)
# POINT Z (10.840998 45.888594 81.1)
# POINT Z (10.840998 45.888594 81.1)

# %% [markdown]
# ## Extracting trajectory segments based on time

# %%
segment_clip = trajectory.get_segment_between(datetime(2021,10,12,13,36,1),datetime(2021,10,12,13,38,51))
print(segment_clip)
# Out:
# Trajectory 1_2021-10-12 13:36:01 (2021-10-12 13:36:01 to 2021-10-12 13:38:49) | Size: 158 | Length: 1457.3m
# Bounds: (10.832986, 45.870462, 10.839058, 45.879066)
# LINESTRING Z (10.832986 45.870462 160.3, 10.833045 45.870534 159.9, 10.83311 45.870598 159.5, 10.833

# %%
segment_clip.plot()
plt.show()

# %% [markdown]
# ## Extracting trajectory segments based on  geometry (i.e. clipping)

# %%
from shapely.geometry import Point, Polygon
latitude=45.88880
longitude=10.84269
p = Point(longitude, latitude)
point = gpd.GeoDataFrame(pd.DataFrame(),
    crs=4326,
    geometry= [p])
distance = 10 # meters
# create a bounding box
xmin, ymax, xmax, ymin = point.to_crs(epsg=32632).buffer(distance).geometry.to_crs(epsg=4326).iloc[0].bounds
polygon = Polygon([(xmin, ymin), (xmin, ymax), (xmax, ymax), (xmax, ymin), (xmin, ymin)])
polygon
# Out:
# <POLYGON ((10.843 45.889, 10.843 45.889, 10.843 45.889, 10.843 45.889, 10.84...>

# %%
intersections = trajectory.clip(polygon)
intersections
# Out:
# TrajectoryCollection with 3 trajectories

# %%
intersections.trajectories[0].plot(linewidth=5, capstyle='round')
plt.show()

# %%
intersections.trajectories[1].plot(linewidth=5, capstyle='round')
plt.show()

# %%
intersections.trajectories[2].plot(linewidth=5, capstyle='round')
plt.show()

# %% [markdown]
# ## Splitting trajectories
#
# Gaps are quite common in trajectories. For example, GPS tracks may contain gaps if moving objects enter tunnels where GPS reception is lost. In other use cases, moving objects may leave the observation area for longer time before returning and continuing their recorded track.
#
# Depending on the use case, we therefore might want to split trajectories at observation gaps that exceed a certain minimum duration:
#
# ### duration 15 minutes

# %%
split = mpd.ObservationGapSplitter(trajectory).split(gap=timedelta(minutes=15))
for traj in split:
    print(traj)
# Out:
# Trajectory 1_0 (2021-10-12 12:01:38 to 2021-10-12 13:47:11) | Size: 5070 | Length: 34131.1m
# Bounds: (10.731099, 45.861882, 10.84785, 45.901398)
# LINESTRING Z (10.847826 45.900222 96.5, 10.84785 45.900264 96.5, 10.847843 45.900125 96.5, 10.847836
# Trajectory 1_2 (2021-10-12 14:24:10 to 2021-10-12 14:36:19) | Size: 461 | Length: 6182.5m
# Bounds: (10.837456, 45.887391, 10.875513, 45.919142)
# LINESTRING Z (10.842638 45.888938 79.4, 10.842624 45.888947 79.5, 10.842587 45.888957 79.5, 10.84259

# %%
fig, axes = plt.subplots(nrows=1, ncols=len(split), figsize=(19,4))
for i, traj in enumerate(split):
    traj.plot(ax=axes[i], linewidth=5.0, capstyle='round', column='speed', vmax=20)

# %% [markdown]
# 1Km

# %%
split = mpd.StopSplitter(trajectory).split(min_duration=timedelta(minutes=15), max_diameter=30, min_length=1000)
for traj in split:
    print(traj)
# Out:
# Trajectory 1_2021-10-12 12:01:38 (2021-10-12 12:01:38 to 2021-10-12 13:47:11) | Size: 5070 | Length: 34131.1m
# Bounds: (10.731099, 45.861882, 10.84785, 45.901398)
# LINESTRING Z (10.847826 45.900222 96.5, 10.84785 45.900264 96.5, 10.847843 45.900125 96.5, 10.847836
# Trajectory 1_2021-10-12 14:24:50 (2021-10-12 14:24:50 to 2021-10-12 14:36:19) | Size: 449 | Length: 6131.0m
# Bounds: (10.837456, 45.887391, 10.875513, 45.919142)
# LINESTRING Z (10.842435 45.889193 81.1, 10.842394 45.889205 81.2, 10.842355 45.889195 81.3, 10.84228

# %%
fig, axes = plt.subplots(nrows=1, ncols=len(split), figsize=(19,4))
for i, traj in enumerate(split):
    traj.plot(ax=axes[i], linewidth=5.0, capstyle='round', column='speed', vmax=20)

# %% [markdown]
# ## Stop detection

# %%
detector = mpd.TrajectoryStopDetector(trajectory)
# %time
# Out:
# CPU times: user 4 µs, sys: 0 ns, total: 4 µs
# Wall time: 7.87 µs

# %% [markdown]
# ### stop duration

# %%
stop_durations = detector.get_stop_time_ranges(min_duration=timedelta(seconds=60), max_diameter=100)
# %time
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 8.34 µs

# %%
for x in stop_durations:
    print(x)
# Out:
# Traj 1: 2021-10-12 12:40:59 - 2021-10-12 12:41:59 (duration: 0 days 00:01:00)
# Traj 1: 2021-10-12 12:45:28 - 2021-10-12 12:46:40 (duration: 0 days 00:01:12)
# Traj 1: 2021-10-12 12:46:42 - 2021-10-12 12:47:49 (duration: 0 days 00:01:07)
# Traj 1: 2021-10-12 12:47:51 - 2021-10-12 12:49:24 (duration: 0 days 00:01:33)
# Traj 1: 2021-10-12 12:50:03 - 2021-10-12 12:51:04 (duration: 0 days 00:01:01)
# Traj 1: 2021-10-12 12:51:06 - 2021-10-12 12:52:45 (duration: 0 days 00:01:39)
# Traj 1: 2021-10-12 13:41:59 - 2021-10-12 14:25:49 (duration: 0 days 00:43:50)
# Traj 1: 2021-10-12 14:34:30 - 2021-10-12 14:36:19 (duration: 0 days 00:01:49)

# %% [markdown]
# ## stop points

# %%
# %%time
stop_points = detector.get_stop_points(min_duration=timedelta(seconds=60), max_diameter=100)
# Out:
# CPU times: user 2.55 s, sys: 21 ms, total: 2.57 s
# Wall time: 2.57 s

# %%
stop_points
# Out:
#                                         geometry          start_time  \
# stop_id
# 1_2021-10-12 12:40:59  POINT (10.78907 45.86501) 2021-10-12 12:40:59
# 1_2021-10-12 12:45:28  POINT (10.78245 45.86780) 2021-10-12 12:45:28
# 1_2021-10-12 12:46:42  POINT (10.78183 45.86863) 2021-10-12 12:46:42
# 1_2021-10-12 12:47:51  POINT (10.78134 45.86950) 2021-10-12 12:47:51
# 1_2021-10-12 12:50:03  POINT (10.77877 45.86941) 2021-10-12 12:50:03
# 1_2021-10-12 12:51:06  POINT (10.77799 45.86928) 2021-10-12 12:51:06
# 1_2021-10-12 13:41:59  POINT (10.84254 45.88899) 2021-10-12 13:41:59
# 1_2021-10-12 14:34:30  POINT (10.87515 45.91913) 2021-10-12 14:34:30
#
#                                  end_time  traj_id  duration_s
# stop_id
# 1_2021-10-12 12:40:59 2021-10-12 12:41:59        1        60.0
# 1_2021-10-12 12:45:28 2021-10-12 12:46:40        1        72.0
# 1_2021-10-12 12:46:42 2021-10-12 12:47:49        1        67.0
# 1_2021-10-12 12:47:51 2021-10-12 12:49:24        1        93.0
# 1_2021-10-12 12:50:03 2021-10-12 12:51:04        1        61.0
# 1_2021-10-12 12:51:06 2021-10-12 12:52:45        1        99.0
# 1_2021-10-12 13:41:59 2021-10-12 14:25:49        1      2630.0
# 1_2021-10-12 14:34:30 2021-10-12 14:36:19        1       109.0

# %% [markdown]
# ## stop segments

# %%
# %%time
stops = detector.get_stop_segments(min_duration=timedelta(seconds=60), max_diameter=100)
# Out:
# CPU times: user 3.28 s, sys: 19.7 ms, total: 3.3 s
# Wall time: 3.48 s

# %%
stops
# Out:
# TrajectoryCollection with 8 trajectories

# %% [markdown]
# ## split a stop

# %%
# %%time
split = mpd.StopSplitter(trajectory).split(min_duration=timedelta(seconds=60), max_diameter=100)
# Out:
# CPU times: user 3.78 s, sys: 19.8 ms, total: 3.8 s
# Wall time: 3.86 s

# %%
split
# Out:
# TrajectoryCollection with 8 trajectories

# %%
for segment in split:
    print(segment)
# Out:
# Trajectory 1_2021-10-12 12:01:38 (2021-10-12 12:01:38 to 2021-10-12 12:40:59) | Size: 1859 | Length: 10497.8m
# Bounds: (10.789892, 45.861981, 10.84785, 45.901398)
# LINESTRING Z (10.847826 45.900222 96.5, 10.84785 45.900264 96.5, 10.847843 45.900125 96.5, 10.847836
# Trajectory 1_2021-10-12 12:41:59 (2021-10-12 12:41:59 to 2021-10-12 12:45:28) | Size: 150 | Length: 647.8m
# Bounds: (10.78315, 45.865551, 10.788879, 45.867858)
# LINESTRING Z (10.788848 45.865551 478.6, 10.788839 45.865583 478.8, 10.788834 45.865623 479.1, 10.78
# Trajectory 1_2021-10-12 12:46:40 (2021-10-12 12:46:40 to 2021-10-12 12:46:42) | Size: 2 | Length: 5.1m
# Bounds: (10.782199, 45.868145, 10.782239, 45.868181)
# LINESTRING Z (10.782239 45.868145 533, 10.782199 45.868181 533.4)
# Trajectory 1_2021-10-12 12:47:49 (2021-10-12 12:47:49 to 2021-10-12 12:47:51) | Size: 2 | Length: 3.1m
# Bounds: (10.781568, 45.869024, 10.781579, 45.869051)
# LINESTRING Z (10.781568 45.869024 548.5, 10.781579 45.869051 549)
# Trajectory 1_2021-10-12 12:49:24 (2021-10-12 12:49:24 to 2021-10-12 12:50:03) | Size: 21 | Length: 86.4m
# Bounds: (10.779572, 45.869424, 10.780548, 45.869678)
# LINESTRING Z (10.780548 45.869618 570.7, 10.780497 45.869637 571.2, 10.780459 45.869661 571.6, 10.78
# Trajectory 1_2021-10-12 12:51:04 (2021-10-12 12:51:04 to 2021-10-12 12:51:06) | Size: 2 | Length: 3.7m
# Bounds: (10.778364, 45.869326, 10.778396, 45.869351)
# LINESTRING Z (10.778396 45.869351 592.1, 10.778364 45.869326 592.4)
# Trajectory 1_2021-10-12 12:52:45 (2021-10-12 12:52:45 to 2021-10-12 13:41:59) | Size: 2809 | Length: 21943.9m
# Bounds: (10.731099, 45.861882, 10.842706, 45.888921)
# LINESTRING Z (10.7771 45.869327 613.5, 10.77706 45.869333 613.9, 10.77702 45.869337 614.4, 10.77698
# Trajectory 1_2021-10-12 14:25:49 (2021-10-12 14:25:49 to 2021-10-12 14:34:30) | Size: 423 | Length: 6002.9m
# Bounds: (10.837456, 45.887391, 10.875513, 45.919142)
# LINESTRING Z (10.842126 45.888566 79.1, 10.842008 45.888542 79.5, 10.841949 45.888514 79.7, 10.84182

# %% [markdown]
# ## Generalizing trajectories
#
# ### Douglas-Peucker algorithm

# %%
trajectory.plot(column='speed', linewidth=5, capstyle='round', figsize=(9,3), legend=True, vmax=20)
plt.show()

# %%
generalized_trajectory = mpd.DouglasPeuckerGeneralizer(trajectory).generalize(tolerance=0.001)
generalized_trajectory.plot(column='speed', linewidth=5, capstyle='round', figsize=(9,3), legend=True, vmax=20)
plt.show()

# %%
print('Original length: %s'%(trajectory.get_length()))
print('Generalized length: %s'%(generalized_trajectory.get_length()))
# Out:
# Original length: 40316.62984538985
# Generalized length: 34969.98458540832

# %% [markdown]
# ###  alternative down-sample the trajectory to ensure a certain time delta between records

# %%
time_generalized = mpd.MinTimeDeltaGeneralizer(trajectory).generalize(tolerance=timedelta(minutes=10))
time_generalized.plot(column='speed', linewidth=5, capstyle='round', figsize=(9,3), legend=True, vmax=20)
plt.show()

# %%
time_generalized.to_point_gdf().head(10)
# Out:
#                      longitude   latitude  altitude  \
# time
# 2021-10-12 12:01:38  10.847826  45.900222      96.5
# 2021-10-12 12:11:38  10.837393  45.874687     118.6
# 2021-10-12 12:21:38  10.830129  45.862466     244.0
# 2021-10-12 12:31:38  10.813936  45.864505     371.3
# 2021-10-12 12:41:38  10.788925  45.865013     477.9
# 2021-10-12 12:51:39  10.778118  45.869216     598.4
# 2021-10-12 13:01:39  10.746818  45.869637     657.8
# 2021-10-12 13:11:39  10.741853  45.885748     656.5
# 2021-10-12 13:21:39  10.774246  45.870862     637.8
# 2021-10-12 13:31:39  10.827858  45.863224     301.4
#
#                                                   geometry  traj_id  \
# time
# 2021-10-12 12:01:38   POINT Z (10.84783 45.90022 96.50000)        1
# 2021-10-12 12:11:38  POINT Z (10.83739 45.87469 118.60000)        1
# 2021-10-12 12:21:38  POINT Z (10.83013 45.86247 244.00000)        1
# 2021-10-12 12:31:38  POINT Z (10.81394 45.86451 371.30000)        1
# 2021-10-12 12:41:38  POINT Z (10.78893 45.86501 477.90000)        1
# 2021-10-12 12:51:39  POINT Z (10.77812 45.86922 598.40000)        1
# 2021-10-12 13:01:39  POINT Z (10.74682 45.86964 657.80000)        1
# 2021-10-12 13:11:39  POINT Z (10.74185 45.88575 656.50000)        1
# 2021-10-12 13:21:39  POINT Z (10.77425 45.87086 637.80000)        1
# 2021-10-12 13:31:39  POINT Z (10.82786 45.86322 301.40000)        1
#
#                          speed        kmh
# time
# 2021-10-12 12:01:38   5.026084  18.093904
# 2021-10-12 12:11:38   4.446633  16.007878
# 2021-10-12 12:21:38   3.863094  13.907137
# 2021-10-12 12:31:38   3.815148  13.734534
# 2021-10-12 12:41:38   3.525257  12.690925
# 2021-10-12 12:51:39   1.619121   5.828837
# 2021-10-12 13:01:39   8.849716  31.858976
# 2021-10-12 13:11:39   6.003111  21.611198
# 2021-10-12 13:21:39  10.406578  37.463682
# 2021-10-12 13:31:39  10.652206  38.347942

# %% [markdown]
# ---
#
# # Exercise
#
# - identify the shortest path by walk to reach the Castle of Trento from the main train station of Trento
# - identify the streets network orientation of the cities: Trento-Italy, Verona-Italy,  Munich-Germany, Athens-Greece
# - locate the student residences of Trento in OpenStreetMap and identify services in an area of 15 minutes based on the concept of [Carlos Moreno](https://twitter.com/CarlosMorenoFr) of [the 15 minute city](https://www.ted.com/talks/carlos_moreno_the_15_minute_city)<br/>
# <i>"...a way to ensure that urban residents can fulfill six essential functions within a 15-minute walk [or bike] from their dwellings: living, working, commerce, healthcare, education and entertainment..."</i>
